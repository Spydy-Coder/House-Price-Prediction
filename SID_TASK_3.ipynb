# %% [markdown]
# # <center>**SPECTRUM INTENSHIP DRIVE 2021.**</center>
#
# ## <center>**Welcome to the Final task of DS/ML internship of SID 2021.**</center>

# %% [markdown]
# ### <center>In the final task we will be learning about various machine learning pipelines starting from fetching data , preprocessing them , feature selection to building models using **3 REGRESSION algorithms (LINEAR REGRESSION, DECISION TREE REGRESSION, RANDOM FOREST REGRESSION)** and comparing their R Squared score and **3 CLASSIFICATION machine learning algorithms (LOGISTIC REGRESSION, DECISION TREE CLASSIFICATION, RANDOM FOREST CLASSIFICATION)** and comparing their accuracy.

# %% [markdown]
# ![Screenshot (176).png](data:image/png;base64,...)

# %% [markdown]
# #### **Perform the following on the dataset:**
# (not necessarily in the same sequence)
#
# - Exploratory data analysis
#
# - Handle the missing values.
#
# - Make a new column called SalePriceClass,  based on the following conditions.
#
#   - if SalePrice greater than or equal 400000 then SalePriceClass = 'A'
#   - if SalePrice between 300000 and 399999 then SalePriceClass = 'B'
#   - if SalePrice between 200000 and 299999 then SalePriceClass = 'C'
#   - if SalePrice between 100000 and 199999 then SalePriceClass = 'D'
#   - if SalePrice less than or equal 100000 then SalePriceClass = 'E'
#
# - Label Encoding
#
# - Feature Selection
#
# - Outlier detection  and removal.
#
# - Data Scaling
#
# - Spliting the data into train and test set.
#
# - Make use of 3 REGRESSION machine learning algorithms (LINEAR REGRESSION ,DECISION TREE REGRESSION, RANDOM FOREST REGRESSION) and compare their R Squared score.(**Target variable - SalePrice**)
#
# - Make use of 3 CLASSIFICATION machine learning algorithms (LOGISTIC REGRESSION ,DECISION TREE CLASSIFICATION, RANDOM FOREST CLASSIFICATION) and compare their accuracy.(**Target variable - SalePriceClass**)
#
# - Try to optimize hyperparameters using RandomizedSearchCV or GridSearchCV.
#
# - Find the best algorithm for Regression and Classification on the given dataset.
#
# **NOTE-Make sure to make use of markdowns and comments.**

# %% [markdown]
# #### **Resources**
#
# Watching:
# - [The 7 steps of machine learning](https://www.youtube.com/watch?v=nKW8Ndu7Mjw)
# - [How to Build a Machine Learning Model](https://www.youtube.com/watch?v=NRnaMCNOK7Y)
# - [StatQuest: Fitting a line to data, aka least squares, aka linear regression.](https://www.youtube.com/watch?v=PaFPbb66DxQ&list=PLblh5JKOoLUIzaEkCLIUxQFjPIlapw8nU&index=1)
# - [Linear Regression](https://youtu.be/E5RjzSK0fvY)
# - [Logistic Regression](https://www.youtube.com/watch?v=XnOAdxOWXWg)
# - [Decision Tree](https://youtu.be/qDcl-FRnwSU)
# - [Random Forest](https://youtu.be/ok2s1vV9XW0)
# - [Regression Trees, Clearly Explained!!!](https://www.youtube.com/watch?v=g9c66TUylZ4&list=PLblh5JKOoLUKAtDViTvRGFpphEc24M-QH&index=3)
#
# Reading:
#
# - [Data Preprocessing from hackernoon](https://hackernoon.com/what-steps-should-one-take-while-doing-data-preprocessing-502c993e1caa)
# - [Data PreProcessing from datadriveninvestor](https://medium.datadriveninvestor.com/data-science-data-preprocessing-eda-6be2860fbb5d)
# - [The 7 Steps of Machine Learning from towardsdatascience](https://towardsdatascience.com/the-7-steps-of-machine-learning-2877d7e5548e)
# - [The Ultimate Guide to Linear Regression for Machine Learning](https://www.keboola.com/blog/linear-regression-machine-learning)
# - [Decision Trees and Random Forests](https://towardsdatascience.com/decision-trees-and-random-forests-df0c3123f991)
# - [Decision Trees and Random Forests — Explained](https://towardsdatascience.com/decision-tree-and-random-forest-explained-8d20ddabc9dd)
# - [Evaluation Metrics for Regression Model](https://www.analyticsvidhya.com/blog/2021/05/know-the-best-evaluation-metrics-for-your-regression-model/)
# - [Hyperparameter tuning with GridSearchCV and RandomizedSearchCV](https://towardsdatascience.com/machine-learning-gridsearchcv-randomizedsearchcv-d36b89231b10)
# - [Random Search to Optimize Hyperparameters](https://www.section.io/engineering-education/random-search-hyperparameters/)

# %% [markdown]
# ### NOTE-The below layout is made just for convenience. Add or delete cells and sub-sections according to your own requirement

# %% [markdown]
# # Loading Data

# %%
# Run this cell to download the dataset required for this task
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1WoXkw5WKJnquoTqh25B70qFkVO-vaQgp' -O 'final_task.csv'
# Out:
# --2021-07-31 06:12:05--  https://docs.google.com/uc?export=download&id=1WoXkw5WKJnquoTqh25B70qFkVO-vaQgp
# Resolving docs.google.com (docs.google.com)... 108.177.126.102, 108.177.126.138, 108.177.126.100, ...
# Connecting to docs.google.com (docs.google.com)|108.177.126.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-ak-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/adl19ur8chj31f6i4j90pk7o0nf6o8vo/1627711875000/03131713557125907988/*/1WoXkw5WKJnquoTqh25B70qFkVO-vaQgp?e=download [following]
# ...
# --2021-07-31 06:12:06--  https://doc-14-ak-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/adl19ur8chj31f6i4j90pk7o0nf6o8vo/1627711875000/03131713557125907988/*/1WoXkw5WKJnquoTqh25B70qFkVO-vaQgp?e=download
# Resolving doc-14-ak-docs.googleusercontent.com (doc-14-ak-docs.googleusercontent.com)... 108.177.119.132, 2a00:1450:4013:c00::84
# ...

# %% [markdown]
# # Understanding and handling data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import explained_variance_score
from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression 
df=pd.read_csv("/content/final_task.csv") 
plt.style.use(style='ggplot')
plt.rcParams['figure.figsize'] = (10, 6)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
print(df.shape)
print(df.info())
# Out:
# (1460, 81)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# PoolQC          1453
# MiscFeature     1406
# Alley           1369
# Fence           1179
# FireplaceQu      690
# LotFrontage      259
# GarageCond        81
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# BsmtExposure      38
# BsmtFinType2      38
# BsmtFinType1      37
# BsmtCond          37
# BsmtQual          37
# MasVnrArea         8
# MasVnrType         8
# Electrical         1
# Utilities          0
# dtype: int64

# %% [markdown]
# PoolQC refers to the Pool Quality.Pool Quality is NaN when PoolArea is 0,or there is no Pool. We can calculate the percentage of missing data(null values).

# %%
miss_per=df.isnull().sum()*100/len(df)
miss_per.sort_values(ascending=False,inplace=True)
miss_per.head(10)
# Out:
# PoolQC          99.520548
# MiscFeature     96.301370
# Alley           93.767123
# Fence           80.753425
# FireplaceQu     47.260274
# LotFrontage     17.739726
# GarageCond       5.547945
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# dtype: float64

# %% [markdown]
# ## **EDA**

# %% [markdown]
# We can see that the above first 4 columns have more than 70 % missing data,so it is offcourse that we have to ewmove it.For FireplaceQu with 47% missing data, we decided to also remove it.

# %%
df.drop(['Alley','PoolQC', 'FireplaceQu','Fence', 'MiscFeature'], axis=1, inplace=True)

# %%
df.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
print("Skew is:",df.SalePrice.skew())
plt.hist(df.SalePrice,color='green')
plt.show()
# Out:
# Skew is: 1.8828757597682129

# %% [markdown]
# We use np.log() to transform df.SalePrice and then we calculate the skewness and plot the data again. A value closer to 0 means that we have improved the skewness of data.

# %%
target = np.log(df.SalePrice)
print ("Skew is:", target.skew())
plt.hist(target, color='blue')
plt.show()
df.SalePrice
# Out:
# Skew is: 0.12133506220520406
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
numeric_features = df.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %% [markdown]
# The DataFrame.corr() method displays the correlation (or relationship) between the columns. We’ll examine the correlations between the features and the target.

# %%
corr = numeric_features.corr()
print (corr['SalePrice'].sort_values(ascending=False)[:5], '\n')
print (corr['SalePrice'].sort_values(ascending=False)[-5:])
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# Name: SalePrice, dtype: float64
#
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# The first five features are the most positively correlated with SalePrice, while the next five are the most negatively correlated.

# %%
df.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2])

# %% [markdown]
# The OverallQuall data are integer valued in the interval 1 to 10 inclusive.
# We can create a pivot table to further investigate the relationship between OverallQual and SalePrice. We set index='OverallQual' and values='SalePrice'. We chose to look at the median here.

# %%
pivot = df.pivot_table(index='OverallQual',
                  values='SalePrice', aggfunc=np.median)
pivot
# Out:
#              SalePrice
# OverallQual
# 1                50150
# 2                60000
# 3                86250
# 4               108000
# 5               133000
# 6               160000
# 7               200141
# 8               269750
# 9               345000
# 10              432390

# %% [markdown]
# We can visualise this pivot table with a bar plot.

# %%
pivot.plot(kind='bar', color='blue')
plt.xlabel('Overall Quality')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# Now we will use scatterplot to visualise the relationship between Ground Living Area and salesprice.

# %%
plt.scatter(x=df['GrLivArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Ground living area square feet')
plt.show()

# %% [markdown]
# We can see that as the living area increases the corresponding price also increases. We can do this for Garage Area.

# %%
plt.scatter(x=df['GarageArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %% [markdown]
# We can notice that there are many homes with 0 for Garage Area which indicates that they don't have a garage.
# There are few outliers too so we can also remove that.
# Let's make a new dataframe with some outliers deleted.

# %%
df= df[df['GarageArea'] < 1200]
df.shape
# Out:
# (1455, 76)

# %% [markdown]
# Let's see the scatter plot again.

# %%
plt.scatter(x=df['GarageArea'], y=np.log(df.SalePrice))
plt.xlim(-200,1600)
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Non-Numeric data

# %%
categorical_feature = df.select_dtypes(exclude=[np.number])

# %% [markdown]
# Let's see the Street Column which indicates whether there is Gravel or Pave road access to the property.

# %%
print (df.Street.value_counts(), "\n")
# Out:
# Pave    1450
# Grvl       5
# Name: Street, dtype: int64

# %% [markdown]
# In the Street column, the unique values are Pave and Grvl. In the training set, only 5 homes have gravel access. Our model needs numerical data, so we will use one-hot encoding to transform the data into a Boolean column.
# We will create a new column enc_street. In which 1 stands for Pave and 0 stands for Grvl or we can say that 1 means Pave and 0 stands for not Pave.

# %%
df['enc_street'] = pd.get_dummies(df.Street, drop_first=True)
print(df.enc_street.value_counts())
# Out:
# 1    1450
# 0       5
# Name: enc_street, dtype: int64

# %% [markdown]
# Notice that Partial has a significantly higher Median Sale Price than the others. We will encode this as a new feature. We select all of the houses where SaleCondition is equal to Patrial and assign the value 1, otherwise assign 0.

# %%
def encode(x):
  if x=='Partial' :
    return 1
  else:
    return 0
df['enc_condition']=df.SaleCondition.apply(encode)

# %%
condition_pivot = df.pivot_table(index='enc_condition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='green')
plt.xlabel('Encoded Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# We still have missing data so we will either fill the missing values with average value or we can drop them.

# %%
df.fillna(df.mean(),inplace=True)
df.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# GarageType      81
# GarageCond      81
# GarageFinish    81
# GarageQual      81
# BsmtFinType2    38
# BsmtExposure    38
# BsmtQual        37
# BsmtCond        37
# BsmtFinType1    37
# MasVnrType       8
# Electrical       1
# YearRemodAdd     0
# BsmtFinSF1       0
# RoofStyle        0
# RoofMatl         0
# Exterior2nd      0
# Exterior1st      0
# YearBuilt        0
# ExterQual        0
# ExterCond        0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

for feature in categorical_feature:
    df[feature] = pd.get_dummies(df[feature], drop_first=True)
df.head()
# Out:
#    Id  MSSubClass  MSZoning  ...  SalePrice  enc_street  enc_condition
# 0   1          60         0  ...     208500           1              0
# 1   2          20         0  ...     181500           1              0
# 2   3          60         0  ...     223500           1              0
# 3   4          70         0  ...     140000           1              0
# 4   5          60         0  ...     250000           1              0
#
# [5 rows x 78 columns]

# %% [markdown]
# # Feature Selection

# %% [markdown]
# We will seperate the features and the target variable for modelling.We will assign the features to X and the target variable to y.

# %%
y=np.log(df.SalePrice)
X=df.drop(['SalePrice','Id'],axis=1)

# %% [markdown]
# We will divide the data into X_train,X_test,y_train,y_test.
# Partitioning the data in this way allows us to evaluate how our model might perform on data that it has never seen before.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=.33)

# %% [markdown]
# DATA SCALING

# %%
from sklearn.preprocessing import MinMaxScaler

feature_scale  = [feature for feature in df.columns if feature not in ['Id','SalePrice']]
scaler = MinMaxScaler()
df[feature_scale] = scaler.fit_transform(df[feature_scale])
df.head()
# Out:
#    Id  MSSubClass  MSZoning  ...  SalePrice  enc_street  enc_condition
# 0   1    0.235294       0.0  ...     208500         1.0            0.0
# 1   2    0.000000       0.0  ...     181500         1.0            0.0
# 2   3    0.235294       0.0  ...     223500         1.0            0.0
# 3   4    0.294118       0.0  ...     140000         1.0            0.0
# 4   5    0.235294       0.0  ...     250000         1.0            0.0
#
# [5 rows x 78 columns]

# %% [markdown]
# # Model Building

# %% [markdown]
# #### REGRESSION

# %% [markdown]
# 1)LINEAR REGRESSION

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %% [markdown]
# We fit the model using X_train and y_train, and we’ll score with X_test and y_test.

# %%
from sklearn.metrics import mean_squared_error
lr.fit(X_train, y_train)
lr_score = lr.score(X_test,y_test)
pred_mlr = lr.predict(X_test)
expl_mlr = explained_variance_score(pred_mlr,y_test)
print ('RMSE is: \n', mean_squared_error(y_test, pred_mlr))
# Out:
# RMSE is:
#  0.017350185980195713

# %% [markdown]
# 2)DECISION TREE REGRESSION

# %%
tr_regressor = DecisionTreeRegressor(random_state=0)
tr_regressor.fit(X_train,y_train)
tr_regressor.score(X_test,y_test)
pred_tr = tr_regressor.predict(X_test)
decision_score=tr_regressor.score(X_test,y_test)
expl_tr = explained_variance_score(pred_tr,y_test)
print ('RMSE is: \n', mean_squared_error(y_test, pred_tr))
# Out:
# RMSE is:
#  0.048712604057894106

# %% [markdown]
# 3)RANDOM FOREST REGRESSION

# %%
rf_regressor = RandomForestRegressor(n_estimators=28,random_state=0)
rf_regressor.fit(X_train,y_train)
rf_regressor.score(X_test,y_test)
rf_pred =rf_regressor.predict(X_test)
rf_score=rf_regressor.score(X_test,y_test)
expl_rf = explained_variance_score(rf_pred,y_test)
print ('RMSE is: \n', mean_squared_error(y_test, rf_pred))
# Out:
# RMSE is:
#  0.020133046499607704

# %% [markdown]
# Checking Model Performance

# %%
print("Multiple Linear Regression Model Score is ",round(lr_score*100))
print("Decision tree  Regression Model Score is ",round(decision_score*100))
print("Random Forest Regression Model Score is ",round(rf_score*100))

#Let's have a tabular pandas data frame, for a clear comparison

models_score =pd.DataFrame({'Model':['Multiple Linear Regression','Decision Tree','Random forest Regression'],
                            'Score':[lr_score,decision_score,rf_score],
                            'Explained Variance Score':[expl_mlr,expl_tr,expl_rf]
                           })
models_score.sort_values(by='Score',ascending=False)
# Out:
# Multiple Linear Regression Model Score is  89
# Decision tree  Regression Model Score is  69
# Random Forest Regression Model Score is  87
#                         Model     Score  Explained Variance Score
# 0  Multiple Linear Regression  0.891327                  0.880258
# 2    Random forest Regression  0.873896                  0.842241
# 1               Decision Tree  0.694888                  0.718639

# %% [markdown]
# We can conclude that Multiple Linear Regression is the best algorithm to find housing prices among these above algorithms.

# %% [markdown]
# #### CLASSIFICATION

# %%
df["SaleCategory"] = np.NAN

for i,j in df.iterrows():

  if df.SalePrice[i] >= 400000:

    df.SaleCategory[i] = 'A'

  elif df.SalePrice[i]>= 300000:

    df.SaleCategory[i] ='B'

  elif df.SalePrice[i]>= 200000:

    df.SaleCategory[i] = 'C'

  else:

    df.SaleCategory[i] = 'D'
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# 1)Logistic Regression

# %%
y1=df.SaleCategory
X1=df.drop(['SalePrice','Id','SaleCategory'],axis=1)
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, random_state=42, test_size=.33)
kr=LogisticRegression()
kr.fit(X_train,y_train1)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn import metrics 
y_pred1 = kr.predict(X_test1)
accuracy = metrics.accuracy_score(y_test1, y_pred1)
accuracy_percentage = 100 * accuracy
print("Accuracy Percentage=")
accuracy_percentage
# Out:
# Accuracy Percentage=
# 42.82744282744283

# %% [markdown]
# 2)Decision Tree Classification

# %%
from sklearn.tree import DecisionTreeClassifier
decision_tree=DecisionTreeClassifier()
decision_tree.fit(X_train1,y_train1)
y_predict2=decision_tree.predict(X_test1)
accuracy_tree=metrics.accuracy_score(y_test1,y_predict2)
accuracy_tree_per=accuracy_tree*100
print("Accuracy Percentage=")
accuracy_tree_per
# Out:
# Accuracy Percentage=
# 85.44698544698545

# %% [markdown]
# 3)Random Forest Classification

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier(n_estimators=100)

# %%
clf.fit(X_train1,y_train1)
y_predict3=clf.predict(X_test1)
accuracy_forest=metrics.accuracy_score(y_test1,y_predict3)
accuracy_forest_per=accuracy_forest*100
print("Accuracy Percentage=")
accuracy_forest_per
# Out:
# Accuracy Percentage=
# 88.56548856548856

# %%
models_score1 =pd.DataFrame({'Model':['Logistic Regression','Decision Tree Classification','Random Forest Classification'],
                            'Accuracy_per':[accuracy_percentage,accuracy_tree_per,accuracy_forest_per],
                           })
models_score1.sort_values(by='Accuracy_per',ascending=False)
# Out:
#                           Model  Accuracy_per
# 2  Random Forest Classification     88.565489
# 1  Decision Tree Classification     85.446985
# 0           Logistic Regression     42.827443

# %% [markdown]
# From above accuracy percentage we can conclude that Random Forest Classification is the best method among these three methods.

# %% [markdown]
# ## <center>**GOOD JOB!!!**
# ## <center> WITH YOUR DEDICATION AND PERSISTENCE YOU FINALLY MADE IT TO THE END AND COMPLETED THIS INTERNSHIP.
# ## <center> BUT THIS IS JUST THE BEGINNING .KEEP EXPLORING AND LEARNING.
#
# ## <center> **HAPPY MACHINE LEARNING!!!**
